# %% [markdown]
# # Fundamentals of Pandas

# %% [markdown]
# Read a CSV file and insert the values in a DataFrame:

# %%
# %matplotlib inline
import numpy as np
import pandas as pd

df = pd.read_csv("CarVideos.csv")
df.head()
# Out:
#    Video ID  Vehicle  Conditions   Time
# 0         1  Model 3  Light Rain   8:03
# 1         2  Model S  Heavy Rain   9:04
# 2         3  Model X  Light Rain  13:13
# 3         4  Model 3       Clear  15:34
# 4         5  Model 3       Clear   7:03

# %% [markdown]
# head() is a handy way to visualize what you've loaded. You can pass it an integer to see some specific number of rows at the beginning of your DataFrame:

# %%
df.head(10)
# Out:
#    Video ID  Vehicle  Conditions   Time
# 0         1  Model 3  Light Rain   8:03
# 1         2  Model S  Heavy Rain   9:04
# 2         3  Model X  Light Rain  13:13
# 3         4  Model 3       Clear  15:34
# 4         5  Model 3       Clear   7:03
# 5         6  Model X       Clear   5:03
# 6         7  Model 3  Light Rain  19:45
# 7         8  Model S  Heavy Rain  21:33
# 8         9  Model 3       Clear   8:33
# 9        10  Model 3       Clear  11:53

# %% [markdown]
# You can also view the end of your data with tail():

# %%
df.tail(4)
# Out:
#     Video ID  Vehicle Conditions   Time
# 8          9  Model 3      Clear   8:33
# 9         10  Model 3      Clear  11:53
# 10        11  Model X      Clear   8:22
# 11        12  Model X      Clear  18:43

# %% [markdown]
# We often talk about the "shape" of your DataFrame. This is just its dimensions. This particular CSV file has 12 rows with 4 columns per row:

# %%
df.shape
# Out:
# (12, 4)

# %% [markdown]
# The total size of the data frame is the rows * columns:

# %%
df.size
# Out:
# 48

# %% [markdown]
# The len() function gives you the number of rows in a DataFrame:

# %%
len(df)
# Out:
# 12

# %% [markdown]
# If your DataFrame has named columns (in our case, extracted automatically from the first row of a .csv file,) you can get an array of them back:

# %%
df.columns
# Out:
# Index(['Video ID', 'Vehicle', 'Conditions', 'Time'], dtype='object')

# %% [markdown]
# Extracting a single column from your DataFrame looks like this - this gives you back a "Series" in Pandas:

# %%
df['Time']
# Out:
# 0      8:03
# 1      9:04
# 2     13:13
# 3     15:34
# 4      7:03
# 5      5:03
# 6     19:45
# 7     21:33
# 8      8:33
# 9     11:53
# 10     8:22
# 11    18:43
# Name: Time, dtype: object

# %% [markdown]
# You can also extract a given range of rows from a named column:

# %%
df['Time'][:5]
# Out:
# 0     8:03
# 1     9:04
# 2    13:13
# 3    15:34
# 4     7:03
# Name: Time, dtype: object

# %% [markdown]
# Or even extract a single value from a specified column / row combination:

# %%
df['Time'][5]
# Out:
# '5:03'

# %% [markdown]
# To extract more than one column, you need to pass in an array of column names instead of a single one:

# %%
df[['Vehicle', 'Time']]
# Out:
#     Vehicle   Time
# 0   Model 3   8:03
# 1   Model S   9:04
# 2   Model X  13:13
# 3   Model 3  15:34
# 4   Model 3   7:03
# 5   Model X   5:03
# 6   Model 3  19:45
# 7   Model S  21:33
# 8   Model 3   8:33
# 9   Model 3  11:53
# 10  Model X   8:22
# 11  Model X  18:43

# %% [markdown]
# You can also extract specific ranges of rows from more than one column:

# %%
df[['Vehicle', 'Time']][:5]
# Out:
#    Vehicle   Time
# 0  Model 3   8:03
# 1  Model S   9:04
# 2  Model X  13:13
# 3  Model 3  15:34
# 4  Model 3   7:03

# %% [markdown]
# Sorting your DataFrame by a specific column looks like this:

# %%
df.sort_values(['Vehicle'])
# Out:
#     Video ID  Vehicle  Conditions   Time
# 0          1  Model 3  Light Rain   8:03
# 3          4  Model 3       Clear  15:34
# 4          5  Model 3       Clear   7:03
# 6          7  Model 3  Light Rain  19:45
# 8          9  Model 3       Clear   8:33
# 9         10  Model 3       Clear  11:53
# 1          2  Model S  Heavy Rain   9:04
# 7          8  Model S  Heavy Rain  21:33
# 2          3  Model X  Light Rain  13:13
# 5          6  Model X       Clear   5:03
# 10        11  Model X       Clear   8:22
# 11        12  Model X       Clear  18:43

# %% [markdown]
# You can break down the number of unique values in a given column into a Series using value_counts() - this is a good way to understand the distribution of your data:

# %%
vehicle_counts = df['Vehicle'].value_counts()
vehicle_counts
# Out:
# Model 3    6
# Model X    4
# Model S    2
# Name: Vehicle, dtype: int64

# %% [markdown]
# Pandas even makes it easy to plot a Series or DataFrame - just call plot():

# %%
vehicle_counts.plot(kind='bar')
